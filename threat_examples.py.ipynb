# %%
import sparql_dataframe

import pandas
endpoint = "http://172.23.0.2:8890/sparql"
#pandas.set_option('display.max_rows', None)

prefixes = """

prefix dct:	<http://purl.org/dc/terms/>
prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#>
prefix samm: <https://owaspsamm.org/model/>
prefix enisa: <https://par-tec.it/onto/enisa/>
prefix ethreat: <https://par-tec.it/onto/enisa/threat/>
prefix pt: <https://par-tec.it/security/>
prefix dct: <http://purl.org/dc/terms/>
prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#>
prefix d3f: <http://d3fend.mitre.org/ontologies/d3fend.owl#> 

"""

q = """


    SELECT * WHERE {
    
    # ?s a enisa:Threat;
       rdfs:label ?label
    }
    
"""

df = sparql_dataframe.get(endpoint, prefixes + q)

# %%
df
# Out:
#                                            s  \
# 0   https://par-tec.it/onto/enisa/threat/154
# 1   https://par-tec.it/onto/enisa/threat/100
# 2   https://par-tec.it/onto/enisa/threat/103
# 3   https://par-tec.it/onto/enisa/threat/107
# 4    https://par-tec.it/onto/enisa/threat/11
# ..                                       ...
# 70   https://par-tec.it/onto/enisa/threat/93
# 71   https://par-tec.it/onto/enisa/threat/94
# 72   https://par-tec.it/onto/enisa/threat/95
# 73   https://par-tec.it/onto/enisa/threat/96
# 74   https://par-tec.it/onto/enisa/threat/98
#
#                                                 label
# 0                             Unauthorized activities
# 1                      Receive of unsolicited E-mail
# 2                                   Denial of service
# 3                  Malicious code/ software/ activity
# 4                         Information leakage/sharing
# ..                                                ...
# 70                              Interfering radiation
# 71                                 Replay of messages
# 72  Network Reconnaissance, Network traffic manipu...
# 73              Man in the middle/ Session hijacking
# 74          Identity theft (Identity Fraud/ Account)
#
# [75 rows x 2 columns]

# %%
q_default="""
SELECT DISTINCT ?g 
WHERE { 
  GRAPH ?g {?s ?p ?o}
} 
"""
sparql_dataframe.get(endpoint, q_default)
# Out:
#                                                g
# 0     http://www.openlinksw.com/schemas/virtrdf#
# 1                      http://www.w3.org/ns/ldp#
# 2                    urn:activitystreams-owl:map
# 3                   http://localhost:8890/sparql
# 4                     http://localhost:8890/DAV/
# 5                 http://www.w3.org/2002/07/owl#
# 6  https://w3id.org/italia/controlled-vocabulary

# %%
d3f_classes_by_threat = """
SELECT ?threat, ?target
WHERE {

# ?t pt:affects ?d3f_class;
  rdfs:label ?threat
.
# ?d3f_subclass (<>|!<>)*  ?d3f_class;
   a ?d3f_type ;
   rdfs:label ?target
   
.

}

"""

df = sparql_dataframe.get(endpoint, prefixes+ d3f_classes_by_threat)

# %%
df
# Out:
#                        threat  \
# 0     Abuse of authorizations
# 1     Abuse of authorizations
# 2     Abuse of authorizations
# 3     Abuse of authorizations
# 4     Abuse of authorizations
# ...                       ...
# 9995  Abuse of authorizations
# 9996  Abuse of authorizations
# 9997  Abuse of authorizations
# 9998  Abuse of authorizations
# 9999  Abuse of authorizations
#
#                                                  target
# 0                     Authentication Event Thresholding
# 1                     Authentication Event Thresholding
# 2                     Authentication Event Thresholding
# 3                     Authentication Event Thresholding
# 4                     Authentication Event Thresholding
# ...                                                 ...
# 9995  Reference - CAR-2021-05-003: BCDEdit Failure R...
# 9996  Reference - CAR-2021-05-004: BITS Job Persiste...
# 9997  Reference - CAR-2021-05-004: BITS Job Persiste...
# 9998  Reference - CAR-2021-05-004: BITS Job Persiste...
# 9999  Reference - CAR-2021-05-004: BITS Job Persiste...
#
# [10000 rows x 2 columns]

# %%
add_triples = """

prefix d3f: <http://d3fend.mitre.org/ontologies/d3fend.owl#> 
prefix dct: <http://purl.org/dc/terms/> 
prefix ethreat: <https://par-tec.it/onto/enisa/threat/> 
prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> 
prefix skos:    <http://www.w3.org/2004/02/skos/core#>
prefix pt: <https://par-tec.it/security/> 

INSERT IN GRAPH <https://w3id.org/italia/controlled-vocabulary>
  { 
  ethreat:176 pt:affects d3f:AuthorizationService ;
    pt:affects d3f:Authorization ;
    pt:affects d3f:Authentication

  . }  

"""

# %%
# Defensive techniquest for a given threat

d3f_classes_by_threat = """
SELECT DISTINCT 

# ?threat, ?target, ?d3f_subclass

WHERE {

# ?t pt:affects ?d3f_class;
  rdfs:label ?threat
.

# ?d3f_subclass (<>|!<>)*   ?d3f_class;
   a ?d3f_type ;
   rdfs:label ?target
   
. 
# ?d3f_class  a d3f:DefensiveTechnique



}

"""

df = sparql_dataframe.get(endpoint, prefixes+ d3f_classes_by_threat)

# %%
df
# Out:
# Empty DataFrame
# Columns: [threat, target, d3f_subclass]
# Index: []

# %%
# Defensive techniquest for a given threat

d3f_classes_by_threat = """
SELECT DISTINCT 

# ?threat, ?measures, ?d3f_subclass, ?text

WHERE {

# ?t pt:affects ?d3f_class;
  rdfs:label ?threat
.
# ?d3f_subclass (<>|!<>)*   d3f:PlatformHardening;
   a ?d3f_type ;
   rdfs:label ?measures;
   d3f:definition ?text
   
.

}

"""

df = sparql_dataframe.get(endpoint, prefixes+ d3f_classes_by_threat)
df
# Out:
#                      threat                          measures  \
# 0   Abuse of authorizations         Bootloader Authentication
# 1   Abuse of authorizations                   Disk Encryption
# 2   Abuse of authorizations    Driver Load Integrity Checking
# 3   Abuse of authorizations           Executable Allowlisting
# 4   Abuse of authorizations                   File Encryption
# 5   Abuse of authorizations            Local File Permissions
# 6   Abuse of authorizations                Platform Hardening
# 7   Abuse of authorizations                      RF Shielding
# 8   Abuse of authorizations                   Software Update
# 9   Abuse of authorizations  System Configuration Permissions
# 10  Abuse of authorizations                TPM Boot Integrity
#
#                                          d3f_subclass  \
# 0   http://d3fend.mitre.org/ontologies/d3fend.owl#...
# 1   http://d3fend.mitre.org/ontologies/d3fend.owl#...
# 2   http://d3fend.mitre.org/ontologies/d3fend.owl#...
# 3   http://d3fend.mitre.org/ontologies/d3fend.owl#...
# 4   http://d3fend.mitre.org/ontologies/d3fend.owl#...
# 5   http://d3fend.mitre.org/ontologies/d3fend.owl#...
# 6   http://d3fend.mitre.org/ontologies/d3fend.owl#...
# 7   http://d3fend.mitre.org/ontologies/d3fend.owl#...
# 8   http://d3fend.mitre.org/ontologies/d3fend.owl#...
# 9   http://d3fend.mitre.org/ontologies/d3fend.owl#...
# 10  http://d3fend.mitre.org/ontologies/d3fend.owl#...
#
#                                                  text
# 0   Cryptographically authenticating the bootloade...
# 1   Encrypting a hard disk partition to prevent cl...
# 2   Ensuring the integrity of drivers loaded durin...
# 3   Using a digital signature to authenticate a fi...
# 4        Encrypting a file using a cryptographic key.
# 5   Restricting access to a local file by configur...
# 6   Hardening components of a Platform with the in...
# 7   Adding physical barriers to a platform to prev...
# 8   Replacing old software on a computer system co...
# 9   Restricting system configuration modifications...
# 10  Assuring the integrity of a platform by demons...

# %% [markdown]
# # SAMM
#
# Overview:
#
# * there are 5 Business Functions mapped as samm:BusinessFunction
# * each BusinessFunction has 3 samm:Practices; I don't know if this number is a constraint or is just for simplicity.

# %%
overview = """

Select ?f_l, ?p_l, ?ptype WHERE {

# ?f a samm:BusinessFunction;
  rdfs:label ?f_l

. 

# ?p _:b ?f;
  rdfs:label ?p_l;
  rdf:type ?ptype


}

"""
sparql_dataframe.get(endpoint, prefixes+ overview)
# Out:
#                f_l                          p_l  \
# 0       Governance           Strategy & Metrics
# 1   Implementation            Secure Deployment
# 2           Design        Security Architecture
# 3       Governance         Education & Guidance
# 4       Operations       Environment Management
# 5     Verification      Architecture Assessment
# 6           Design        Security Requirements
# 7     Verification  Requirements-driven Testing
# 8       Operations       Operational Management
# 9   Implementation                 Secure Build
# 10    Verification             Security Testing
# 11      Governance          Policy & Compliance
# 12      Operations          Incident Management
# 13  Implementation            Defect Management
# 14          Design            Threat Assessment
#
#                                    ptype
# 0   https://owaspsamm.org/model/Practice
# 1   https://owaspsamm.org/model/Practice
# 2   https://owaspsamm.org/model/Practice
# 3   https://owaspsamm.org/model/Practice
# 4   https://owaspsamm.org/model/Practice
# 5   https://owaspsamm.org/model/Practice
# 6   https://owaspsamm.org/model/Practice
# 7   https://owaspsamm.org/model/Practice
# 8   https://owaspsamm.org/model/Practice
# 9   https://owaspsamm.org/model/Practice
# 10  https://owaspsamm.org/model/Practice
# 11  https://owaspsamm.org/model/Practice
# 12  https://owaspsamm.org/model/Practice
# 13  https://owaspsamm.org/model/Practice
# 14  https://owaspsamm.org/model/Practice

# %% [markdown]
# ## Practices
#
# Every Practice is declined in various maturity levels: 1, 2, 3. This number is arbitrary and is constrained for simplicity.

# %%
overview = """

Select * WHERE {

# ?p a samm:MaturityLevel ;
  rdfs:label ?q
. 

}

"""
sparql_dataframe.get(endpoint, prefixes+ overview)
# Out:
#                                                    p  q
# 0  https://owaspsamm.org/model/0a1dc80f84964f2fa7...  1
# 1  https://owaspsamm.org/model/47dd82af343e4695a0...  2
# 2  https://owaspsamm.org/model/7bbfe31d447e48759e...  3

# %% [markdown]
# Activities are labeled in base of 3 maturity levels and two streams A and B.
#
# The streams are arbitrarily two for simplicity. Labels `A` and `B` do not imply any relation of priority.

# %%
overview = """

Select ?practice, ?level, ?description WHERE {


[] a samm:PracticeLevel;  # Return all PracticeLevel...
  dct:description ?description;

  samm:hasPractice [      #   with the associated practice 
    rdfs:label ?practice
  ];
  samm:hasMaturityLevel [ #   and maturity
      rdfs:label ?level
  ]


}
ORDER BY ?practice

"""
sparql_dataframe.get(endpoint, prefixes+ overview)
# Out:
#                        practice  level  \
# 0       Architecture Assessment      1
# 1       Architecture Assessment      2
# 2       Architecture Assessment      3
# 3             Defect Management      3
# 4             Defect Management      1
# 5             Defect Management      2
# 6          Education & Guidance      1
# 7          Education & Guidance      3
# 8          Education & Guidance      2
# 9        Environment Management      3
# 10       Environment Management      2
# 11       Environment Management      1
# 12          Incident Management      2
# 13          Incident Management      3
# 14          Incident Management      1
# 15       Operational Management      3
# 16       Operational Management      2
# 17       Operational Management      1
# 18          Policy & Compliance      2
# 19          Policy & Compliance      1
# 20          Policy & Compliance      3
# 21  Requirements-driven Testing      2
# 22  Requirements-driven Testing      3
# 23  Requirements-driven Testing      1
# 24                 Secure Build      3
# 25                 Secure Build      2
# 26                 Secure Build      1
# 27            Secure Deployment      2
# 28            Secure Deployment      1
# 29            Secure Deployment      3
# 30        Security Architecture      2
# 31        Security Architecture      3
# 32        Security Architecture      1
# 33        Security Requirements      2
# 34        Security Requirements      1
# 35        Security Requirements      3
# 36             Security Testing      2
# 37             Security Testing      1
# 38             Security Testing      3
# 39           Strategy & Metrics      3
# 40           Strategy & Metrics      1
# 41           Strategy & Metrics      2
# 42            Threat Assessment      3
# 43            Threat Assessment      1
# 44            Threat Assessment      2
#
#                                           description
# 0   Review the architecture to ensure baseline mit...
# 1   Review the complete provision of security mech...
# 2   Review the architecture effectiveness and feed...
# 3   Defect tracking across multiple components is ...
# 4        All defects are tracked within each project.
# 5   Defect tracking used to influence the deployme...
# 6   Offer staff access to resources around the top...
# 7   Develop in-house training programs facilitated...
# 8   Educate all personnel in the software lifecycl...
# 9   Conformity with continuously improving process...
# 10             Formal process with baselines in place
# 11                 Best-effort patching and hardening
# 12        Formal incident management process in place
# 13                         Mature incident management
# 14        Best-effort incident detection and handling
# 15                     Active Monitoring and Response
# 16                      Managed, Responsive Processes
# 17                             Foundational Practices
# 18  Establish application-specific security and co...
# 19  Identify and document governance and complianc...
# 20  Measure adherence to policies, standards, and ...
# 21  Perform implementation review to discover appl...
# 22  Maintain the application security level after ...
# 23  Opportunistically find basic vulnerabilities a...
# 24  Build process helps prevent known defects from...
# 25  Build process is optimized and fully integrate...
# 26        Build process is repeatable and consistent.
# 27  Deployment processes include security verifica...
# 28         Deployment processes are fully documented.
# 29  Deployment process is fully automated and inco...
# 30  Direct the software design process toward know...
# 31  Formally control the software design process a...
# 32  Insert consideration of proactive security gui...
# 33  Increase granularity of security requirements ...
# 34  Consider security explicitly during the softwa...
# 35  Mandate security requirements process for all ...
# 36  Make security testing during development more ...
# 37  Perform security testing (both manual and tool...
# 38  Embed security testing as part of the developm...
# 39  Align security efforts with the relevant organ...
# 40  Identify objectives and means of measuring eff...
# 41  Establish a unified strategic roadmap for soft...
# 42  Proactive improvement of threat coverage throu...
# 43  Best-effort identification of high-level threa...
# 44  Standardization and enterprise-wide analysis o...

# %% [markdown]
# ## Streams
#
# As we saw before, each security practice is declined in different level of maturity

# %%
overview = """

Select ?stream,  ?letter, ?order, ?description, ?practice WHERE {

[] a samm:Stream;  # Return all Streams...
  rdfs:label ?stream;
  dct:description ?description;

  samm:hasPractice [      #   with the associated practice 
    rdfs:label ?practice
  ];
  samm:hasLetter ?letter ;
  samm:hasOrder ?order


}
ORDER BY ASC (?practice +  ?letter)

"""
sparql_dataframe.get(endpoint, prefixes+ overview)
# Out:
#                                        stream letter  order  \
# 0                    Organization and Culture      B      2
# 1                           Scalable Baseline      A      1
# 2                    Application Risk Profile      A      1
# 3                       Patching and Updating      B      2
# 4                         Architecture Design      A      1
# 5                        Misuse/Abuse Testing      B      2
# 6                       Compliance Management      B      2
# 7                         Measure and Improve      B      2
# 8                       Software Dependencies      B      2
# 9                           Incident Response      B      2
# 10                    Configuration Hardening      A      1
# 11                       Metrics and Feedback      B      2
# 12                     Training and Awareness      A      1
# 13                    Architecture Validation      A      1
# 14                      Technology Management      B      2
# 15                      Software Requirements      A      1
# 16                         Deep Understanding      B      2
# 17                              Build Process      A      1
# 18                          Supplier Security      B      2
# 19                         Create and Promote      A      1
# 20                          Secret Management      B      2
# 21                            Data Protection      A      1
# 22                         Deployment Process      A      1
# 23  System Decomissioning / Legacy Management      B      2
# 24                            Defect Tracking      A      1
# 25                    Architecture Mitigation      B      2
# 26                         Policy & Standards      A      1
# 27                            Threat Modeling      B      2
# 28                       Control Verification      A      1
# 29                         Incident Detection      A      1
#
#                                           description  \
# 0   Organization and culture focuses on promoting ...
# 1   Scalable baseline focuses on the use of applic...
# 2   An application risk profile helps to identify ...
# 3   The activities in this stream focus on the org...
# 4   The design of a software architecture can sign...
# 5   Misuse/Abuse Testing leverages fuzzing, misuse...
# 6   This stream focuses on identifying and providi...
# 7   This stream aims to drive the validity, releva...
# 8   External libraries are a significant part of m...
# 9   Incident Response starts the moment you acknow...
# 10  The activities in this stream focus on the org...
# 11  Defect tracking can drive the improvement of s...
# 12  Training and awareness focuses on increasing t...
# 13  Architecture validation confirms the security ...
# 14  Technologies and frameworks are the cornerston...
# 15  Software requirements specify objectives and e...
# 16  Deep understanding focuses on performing manua...
# 17  A consistent build process ensures the softwar...
# 18  Supplier security deals with requirements that...
# 19  This stream is about creating and promoting an...
# 20  As the secure execution of any software system...
# 21  The activities in this stream focus on ensurin...
# 22  A repeatable and consistent deployment process...
# 23  From the perspective of the organization as a ...
# 24  Defect tracking manages the collection and fol...
# 25  Architecture mitigation focuses on ensuring th...
# 26  This stream focuses on maintaining policies an...
# 27  Threat modeling is intended to help software d...
# 28  Control Verification validates that security c...
# 29  Incident Detection refers to the process of de...
#
#                        practice
# 0          Education & Guidance
# 1              Security Testing
# 2             Threat Assessment
# 3        Environment Management
# 4         Security Architecture
# 5   Requirements-driven Testing
# 6           Policy & Compliance
# 7            Strategy & Metrics
# 8                  Secure Build
# 9           Incident Management
# 10       Environment Management
# 11            Defect Management
# 12         Education & Guidance
# 13      Architecture Assessment
# 14        Security Architecture
# 15        Security Requirements
# 16             Security Testing
# 17                 Secure Build
# 18        Security Requirements
# 19           Strategy & Metrics
# 20            Secure Deployment
# 21       Operational Management
# 22            Secure Deployment
# 23       Operational Management
# 24            Defect Management
# 25      Architecture Assessment
# 26          Policy & Compliance
# 27            Threat Assessment
# 28  Requirements-driven Testing
# 29          Incident Management

# %% [markdown]
# ## Activities
#
# and into two possible streams, resulting in a table of 3 * 2 possible activities for every Practice.
#
# ```
# | Activity | Maturity | Stream |
# | ...      | 1-3      | A-B    |
# ```

# %%
overview = """

Select ?activity,
# ?description, ?letter, ?level, 
# ?url WHERE {

# ?id a samm:Activity;  # Return all Activities...
  dct:description ?description;
  rdfs:seeAlso ?url ;
  skos:altLabel ?activity 
  ; samm:hasStream [      #   with the associated practice 
    samm:hasLetter ?letter
  ];
  samm:hasMaturityLevel [
      rdfs:label ?level
  ]



}

"""
df =sparql_dataframe.get(endpoint, prefixes+ overview)

# %%
print(df.description.values[0])
# Out:
# Security is the responsibility of all employees, not just the Information Security team. Deploy communication and knowledge sharing platforms to help developers build communities around different technologies, tools, and programming languages. In these communities employees share information, discuss challenges with other developers, and search the knowledge base for answers to previously discussed issues.
#
# Form communities around roles and responsibilities and enable developers and engineers from different teams and business units to communicate freely and benefit from each other's expertise. Encourage participation, set up a program to promote those who help the most people as thought leaders, and have management recognize them. In addition to improving application security, this platform may help identify future members of the Secure Software Center of Excellence, or 'Security Champions' based on their expertise and willingness to help others.
#
# The Secure Software Center of Excellence and Application Security teams review the information portal regularly for insights into the new and upcoming technologies, as well as opportunities to assist the development community with new initiatives, tools, programs, and training resources. Use the portal to disseminate information about new standards, tools, and resources to all developers for the continued improvement of SDLC maturity and application security.

# %%
_id.values
# Out:
# array(['https://owaspsamm.org/model/a3720e84d6a24a8ba235c25ce6afc5c7'],
#       dtype=object)
